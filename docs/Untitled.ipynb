# %% [markdown]
# schema can be inferred from the default if the schema doesnt kknopw the type
# the typespace at the interface is small
# its objects, arrays, strings, numbers, nothing
# on the other side its metal or wood

# %% [markdown]
# # operations on the schema
#
# the [applicator] schema designates way schema can be combined generically, in objects, and in arrays.
#
# the generic applicators (ie allOf, oneOf, anyOf, if/then/else) has equivalencies.
#
# we will include type from the validation schema

# %% [markdown]
# # accessible works from scratch

# %% [markdown]
# <q>web accessibility is a world of pain.</q> is an early excerpt in [practice-ability].
# in my accessibility journey i have struggled to find resources to make accessible from scratch.
# there are a lot of resources on how accessibility is violated, but i am curious about how it can be celebrated.
# i've been able to forage some practical resources, but i had to escape technical accessibility media to understand
# how to begin with acessibility.
#
# in the last year, i've put together two presentations that demonstrate the cascading outcomes of accessibility first practices.
# these talks try to escape the pull of technical accessibility by tending towards modern art as a beacon for accessible frameworks.
# the two talks are "practice-ability" and "an anti-social" model of disability.
#
# 1. practice-ability is a ~7min talk that considers an accessibility that uses web content accessibility guidelines and chartability accessibile data visualization heuristics as first and second principles to design accessible technical content.
# 2. an anti-social model of disability is a longer talk that considers how accessibility practices can be developed when we consider modern art as technical advancements of their time. further, it looks at art advocacy as a systemic driver changes that increase access.

# %%
i love performing presentations, but i struggle to find them accessible for a lot of reasons.
practice-ability and anti-social were both performed once (i would love to give them again!)
# Out:
#   Cell In[14], line 1
#     i love performing presentations, but i struggle to find them accessible for a lot of reasons.
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## accessible presentations
#
# the overall theme is that accessible things take time,
# like a presentation they happen in linear times.
# the goals of an acccessible presentation are to be something that
# perceivable, operable, and understandable.
# presentations of this quality will prioritize:
#
# 1. a talk that sounds good.
# 2. media someone can consume in their own space, time, and pace before and after the talk. (ie an assistive, labor-reducing document)
# 3. a presentation that looks consistent with the message.
# 4. a performance
# 5. the videos
#
#
# ### talk, slides, presentation, show, set, video
#
# in designing accessible presentatons we are confronted with ambiguous terms
# talk, slides, document. the process we put forth
#
# use definition list here.
#
# the unifying principle put forth is that a presentation rests as a video.
# it is consumed over time so a targetting video is the goal.
# html is the substrate a canvas for multimedia collage. at rest6

# %% [markdown]
# estimating talk length

# %% [markdown]
# ## presentations that sound good
#
# creating a presentation that sounds good means that a talked needs to be listened to like a song. the sound and message are an outcome of the text and semantics, but independent of the visual.
#
# we isolate how a document sounds be listening to presentation with a synthetic voice repeatly
#
#
#
# effectively, the focus on the sound of
#
#
#
#
#
#
# presentations that sound good require a talk to be listened to.
# the sound depends on the text and semantics in the document, however
# it is unbound by the visual.
#
# a critical skill for designing accessible documents is to know how to use
# a screen reader or TTS system for listening to web content.
#
# functionally, what is said or heard during a talk requires captions.
# the technique of prioritizing how the document sounds is the act of write captions for the video.
#
# ### chance favors the prepared
#
# the largest benefit of preparing the text captions for a talk is that we can listen to the talk
# repeatedly without interrupting the visual and semantic work.
#
# convention says to practice your talk out loud before giving it.
# this approach suggests to listen to your many times and in many contexts
# before practicing your talk.
#
# both i talks i listened to at least ten times before presentating.
# i would play the talks on my screen reader while working, walking, or driving.
# in this repetitive iteration i become very familiar with the messages i wanted to deliever,
# and messages i didn't.

# %% [markdown]
# ## presentations that feel good
#
# making a good textile
#
# a good presentation that feels good makes that participant feel included and considered.
# this often means given them control and preference.
# <q>Explicit is better than implicit.</q>
#
# ### controlling pace
#
# this requires special techniques that are used in the presentations
#
# ### semantics effect the sound
#
# this gets talked about in the feeling

# %% [markdown]
# ## slides that look good
#
# considering visual design last is not a demotion rather it considers the time required for typography and composition. i've practiced calligraphy for a long time, practice-ability contains 9 original works. and, this is possible because i continue draw and design while listening to the talk repeatedly. during which the text is tweaked to sound better, needless text is remove, the typography is adjusted and the compositions lock in.
# at the end, the visuals and text are given time to synchronize into a complete work sensory work that sounds, feels, and looks good.

# %% [markdown]
# ## the videos
#
# these are recordings of both practice-ability and antisocial, and the accessible materials create a cascading outcome of videos. at least, as resssion recording a presentation creates a minimum of two videos:
#
# 1. a recording of the a screen reader reading the talk
# 2. commentary/extras to support the presentation.
#
# a common complaint with screen reader recordings and synthetic voices are the speed. with recordings, audiences can control the video speed and consume the sound at more comfortable paces.
#
#
#
# we won't stop then there are posts about the video. the process of creating
# video is a co-developing activity because it provides screen shots, clips, sharing, transcripts co-development.
#
# learn OBS support open source

# %% [markdown]
# ## the presentation
#
# the caption is the baseline. when using text to speech or a screen reader you won't get sick of the sound of your voice. you'll empathize with other people's realities of using screen readers and synthetic voice services
#
# accessible approaches start with playing and practicing sounds repeating in a garage, eventually you record the jam, and package it. maybe this helps you get shows.
#
# new opportunities for candor in live performances. we commonly see comedians delivering the same sets, but still feeling like its their first time. quite punk. cagean punk
#
# ### commentary on my own presentations
#
#
# practice-ability was a unique performance where during the talk part, i didn't talk. it was my first mobile presentation where i used the screen reader to deliver the talk, samantha even landed some jokes. it mostly worked, 7 minutes was too long for some, but for others it was  good first exposure to a screen reader. me though i didn't know what the heck to do and felt awkward standing there. at the end of the day i felt more prepared for this talk through the process
#
# on my long drive to presnt i decided that if i could find supplies i would paint during my talk. so i found supplies and i had to figure it out. i continued to include the screen reader on mobile device with the screen shared to my laptop. this flexible configuration gave me control when i needed it and start the screen reader auto-pilot in text heavy poritons so i could  reader when i wanted to paint i could run screen reader in text heavy portions. this continued use of this pattern create simulated a nice dialog; it is a technique i would repeat.
#
# fortunately, my friend saul was about to capture a few short clips of these moments.

# %% [markdown]
# it is not to work from what a presentation looks like to something _accessible_, rather to do the work to make something that is perceivable, operable, and understandable.
#
# unconventionally, i decided that the visual aspect was my last design concern instead
# the hierarchy of design goals are:
#
# 1. a talk that sounds good.
# 2. information someone can consume in their own space, time, and pace before and after the talk. (ie an assistive, labor-reducing document)
# 3. a presentation that looks consistent consistents with the information and message.
# 4. a performance

# %% [markdown]
# the rest of this document considers accessible presentations and best practices for making works accessible for in many formats.
#
#
# i believe the best way to integrate accessibility into your work is to integrate it into your practice.
# however, i've struggled to find these ideas in technology based resources.
#
# to get to the place i am writing from i had to read a lot of resources and decide to not read a lot of others.
# it is a tedious process. overall, i've learned that we need to learn how to design accessibile technologies, how
# do we integrate into our work in natural ways.
#
# my autodidactic journey into accessibility brought we making two presentations that i am proud of because
# i believe they demonstrate

# %% [markdown]
# a while ago i gave a talk that i was proud of. i'd like to give it again. HMU.
# i'm proud of it the because
#
# some of the outcomes i appreciate about presentation material:
#
# * they sound good, they are perceivable, operable, and understandable
# * incidentally, they are some of my best visual presentations
# * they are open source
# * they strongly represent women and artists of color
# * i have a lot of formats of content to reuse (eg this post) the process is accretive
#
# ## accessible presentations
#
# presentation? talk? slides? there are ambiguities here.
# however, we can find that there becomes clarity when we apply web accessibility guidelines
# to presentations.
#
# accessible presentations should allow folx:
#
# * to perceive, operate, and understand all the presentation material on their preferred devices with their preferred settings
# * consume/watch presentation material in their own pace, time, and space
#
# ultimately, if we treat a presentation as a video someone could watch rather than a live performance then we tends towards access.
# co-locality and the accessibility supply chain of travel create barriers for viewership, while pre-recording content create
# new opportunities for candor in live performances. we commonly see comedians delivering the same sets, but still feeling like its their first time. quite punk. cagean punk
#
# as video, transcript or descriptive audio is A priority  for pre-recorded content.
# from there we begin our adventures in making something that sounds good even when you're not around, like a song.
#
# my two attempts so far at this approach are
#
# * practice-ability
# * anti-social
#
#
# ## presentations that sound good
#
# who blows hot air when the piano has been drinking too much and the player falls asleep?
# the player piano does. a cyclinder rotates are gushes of air fight through tiny holes to make a sound.
# the cylindrical program is the pre-recorded experience.
#
# so how do i present when i drank too much?
#
#
# ## presentations that feel good
#
# knowing where we are feels are
#
# a relevent python idiom for presentations is to make the implicit explicit.
# the goal is to share information, and that should not be hidden in pure gestalt forms.
#
# the pacing of links on scroll.
#
# ## presentations that look good
#
# i need to acknowledge that i stole a lot of objectivity beautiful visual material. however, in participating in the talk we'll find that this is the goal. sturtevant, after study with an elder duchamp, teaches us everything in modern art is a readymade. even further, we note use of others quotes as readymade texts; a common calligraphers trick.
#
# for both talks, i spend the most revision on what the documents sound like. i listen when i draw, and i draw when i listen. at the end, the words and ideas flow into symbols and images. often they already fit the narrative or better yet their addition and their text description makes the presentation sound better.
#
# ## pre-recorded talks
#
# whether this talk is pre-recorded has some gray area.
# i only gave these talks once, however if i gave them again then they would be pre-recorded (another outcome of the approach).
#
# i'll consider these talks pre-recorded for screen reader users, but not pre-recorded generally as video or audio.
# a critical aspect of the process is the repititive listening
#
# while video was not available ahead of time
#
#
# truth is i never pre-recorded these because each talk was the first time i gave it.
# now, if i give the talk again, then they will be pre-recorded. so lets again.
#
# on second thought, while they weren't pre-recorded as video or audio, they were

# %%
def get_names(object, ns):
    alpha, private = [], []
    for k, v in vars(ns).items():
        if v is object:
            (alpha if k[0].isalpha() else private).append(k)
    return alpha + private

# %%
def get_annotation(object, ns=None):
    if ns is None:
        ns = __import__("__main__")
    annotations = inspect.get_annotations(ns)
    for k in filter(annotations.__contains__, get_names(object, ns)):
        return annotations[k]

# %%
get_annotation(x)
# Out:
# {
#     "type": "string",
#     "examples": [
#         "this",
#         "that"
#     ]
# }

# %%
x
# Out:
# 'this'

# %% [markdown]
# ## equivalencies
#
# any schema can be represented as a oneOf applicator with one element; oneOf is an identity function.

# %% [markdown]
# html tag names are not a type space, they are a namespace that maps to roles where the type space is defined.
# the tags are the letters and the roles are the materials

# %% [markdown]
# https://www.w3.org/WAI/media/av/transcripts/

# %%
## TLDR

# %%
    from jsonschema import ValidationError
    from nbref.schemas import Schema
    from nbref.objects import Dict, Ref

# %%
# %%
#     document = Schema\
# ```yaml
# role: body
# type: array
# prefixItems:
# - role: header
#   type: array
#   prefixItems:
#     -   type: string
#         role: link
#         attrs: {href: "#TOP"}
#         tags: [skip]
#         default: skip to top
#     -   type: string
#         role: link
#         attrs: {href: "#"}
#     -   type: string
#         role: button
#         aria:
#             controls: settings
#         default: settings
#     -   type: string
#         role: link
#         tags: about
#         attrs:
#             href: "about.html"
#         default: "@tonyfast"
# -   $ref: "#/$defs/nb"
# - role: footer
# $defs:
#     nb:
#         properties:
#             metadata:
#                 type: object
#             cells:
#                 type: array
#                 items:
#                     properties:
#                         index:
#                             type: integer
#                         execution_count:
#                             type: integer
#                         source:
#                             type: string
#                             role: textarea
#                         outputs:
#                             type: array
# ```
# Out:
# <pre><code>document = Schema\
# </code></pre>
# <pre><code class="yaml"><div class="highlight"><pre><span></span><span class="nt">role</span><span class="p">:</span><span class="w"> </span><span class="l l-Scalar l-Scalar-Plain">body</span>
# <span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="l l-Scalar l-Scalar-Plain">array</span>
# <span class="nt">prefixItems</span><span class="p">:</span>
# <span class="p p-Indicator">-</span><span class="w"> </span><span class="nt">role</span><span class="p">:</span><span class="w"> </span><span class="l l-Scalar l-Scalar-Plain">header</span>
# <span class="w">  </span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="l l-Scalar l-Scalar-Plain">array</span>
# <span class="w">  </span><span class="nt">prefixItems</span><span class="p">:</span>
# ...

# %%
    document.default()
# Out:
# [
#     {},
#     {},
#     {}
# ]

# %%
x: Schema(type="string", examples=[
    "this", "that"
]) = "this"

# %%
inspect.get_annotations(__import__("__main__"))
# Out:
# {'x': {
#      "type": "string",
#      "examples": [
#          "this",
#          "that"
#      ]
#  }}

# %%
__annotations__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 __annotations__
#
# NameError: name '__annotations__' is not defined

# %%
__annotate__
# Out:
# <function __main__.__annotate__(format, /)>

# %%
s = Schema(type="string", examples=[
    "this", "that"
])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 __annotations__
#
# NameError: name '__annotations__' is not defined

# %%
def test_stuff(object):
    object.validate()
    (~object.schema).xfail(object)



Schema(enum=["a", "b"]).given()(test_stuff)()

# %%
typing.get_type_hints("x", globals())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 typing.get_type_hints("x", globals())
#
# File ~/.pixi/envs/default/lib/python3.14/typing.py:2401, in get_type_hints(obj, globalns, localns, include_extras, format)
#    2398     else:
#    2399         return {k: _strip_annotations(t) for k, t in hints.items()}
# -> 2401 hints = _lazy_annotationlib.get_annotations(obj, format=format)
#    2402 if (
#    2403     not hints
#    2404     and not isinstance(obj, types.ModuleType)
#    (...)   2407     and not hasattr(obj, '__annotate__')
#    2408 ):
#    2409     raise TypeError(f"{obj!r} is not a module, class, or callable.")
#
# File ~/.pixi/envs/default/lib/python3.14/annotationlib.py:1005, in get_annotations(obj, globals, locals, eval_str, format)
#    1003     if isinstance(obj, type) or callable(obj):
#    1004         return {}
# ...

# %%
s.random()
# Out:
# -/\u0019\u009b\u00bb\uda9f\udc03:\u00daK\u00ae\u00b7\ud9dc\udc6c\ud9c3\ude56\u00ce\u0098\ud912\udeae\u0012

# %% [markdown]
# ### type expansions
#
# the type validation can accept a string of a list.
# through expansion can find that the general representation of a type is oneOf.
# in representations it is best to trim excesses of oneOf's with one element, however
# this is the most uniform is the expanded view.

# %%
Schema(dict(type=["integer"]), dict(type=["strung"]))["type"]
# Out:
# [
#     "integer"
# ]

# %%
# %%
#     schema = Schema\
# ```yaml
# type: [integer, string]
# maxLength: 10
# maximum: 20
# ```
# Out:
# <pre><code>schema = Schema\
# </code></pre>
# <pre><code class="yaml"><div class="highlight"><pre><span></span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="p p-Indicator">[</span><span class="nv">integer</span><span class="p p-Indicator">,</span><span class="w"> </span><span class="nv">string</span><span class="p p-Indicator">]</span>
# <span class="nt">maxLength</span><span class="p">:</span><span class="w"> </span><span class="l l-Scalar l-Scalar-Plain">10</span>
# <span class="nt">maximum</span><span class="p">:</span><span class="w"> </span><span class="l l-Scalar l-Scalar-Plain">20</span>
# </pre></div>
# </code></pre>

# %%
schema.expand()
# Out:
# {
#     "oneOf": [
#         {
#             "type": "integer",
#             "maxLength": 10,
#             "maximum": 20
#         },
#         {
#             "type": "string",
#             "maxLength": 10,
#             "maximum": 20
#         }
#     ]
# }

# %%
from nbref.schemas import Metadata

# %%
# %%
#     Schema(
# ```yaml
# oneOf:
# - type: [string, integer]
# - type: object
# ```
#     ).expand()
# Out:
# {
#     "oneOf": [
#         {
#             "type": [
#                 "string",
#                 "integer"
#             ]
#         },
#         {
#             "type": "object"
#         }
#     ]
# }
# <pre><code>Schema(
# </code></pre>
# <pre><code class="yaml"><div class="highlight"><pre><span></span><span class="nt">oneOf</span><span class="p">:</span>
# <span class="p p-Indicator">-</span><span class="w"> </span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="p p-Indicator">[</span><span class="nv">string</span><span class="p p-Indicator">,</span><span class="w"> </span><span class="nv">integer</span><span class="p p-Indicator">]</span>
# <span class="p p-Indicator">-</span><span class="w"> </span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="l l-Scalar l-Scalar-Plain">object</span>
# </pre></div>
# </code></pre>
# <pre><code>).expand()</code></pre>

# %%
Schema({"$ref": Metadata.ref}).expand()["properties"]
# Out:
# {
#     "title": {
#         "type": "string"
#     },
#     "description": {
#         "type": "string"
#     },
#     "default": true,
#     "deprecated": {
#         "type": "boolean",
#         "default": false
#     },
#     "readOnly": {
#         "type": "boolean",
#         "default": false
#     },
#     "writeOnly": {
#         "type": "boolean",
#         "default": false
#     },
#     "examples": {
#         "type": "array",
#         "items": true
#     }
# }

# %%
Schema(oneOf=[Schema(
    schema, type=x
) for x in schema["type"]])
# Out:
# {
#     "oneOf": [
#         {
#             "type": "integer",
#             "maxLength": 10,
#             "maximum": 20
#         },
#         {
#             "type": "string",
#             "maxLength": 10,
#             "maximum": 20
#         }
#     ]
# }

# %%
# %%
# ```yaml
# schema:
#     type: integer
# equivalencies:
#     - schema:
#         type: [integer]
#       equivalencies:
#         - oneOf:
#             type: integer
# ```
# Out:
# {'schema': {'type': 'integer'},
#  'equivalencies': [{'schema': {'type': ['integer']},
#    'equivalencies': [{'oneOf': {'type': 'integer'}}]}]}
# <pre><code class="yaml"><div class="highlight"><pre><span></span><span class="nt">schema</span><span class="p">:</span>
# <span class="w">    </span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="l l-Scalar l-Scalar-Plain">integer</span>
# <span class="nt">equivalencies</span><span class="p">:</span>
# <span class="w">    </span><span class="p p-Indicator">-</span><span class="w"> </span><span class="nt">schema</span><span class="p">:</span>
# <span class="w">        </span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="p p-Indicator">[</span><span class="nv">integer</span><span class="p p-Indicator">]</span>
# <span class="w">      </span><span class="nt">equivalencies</span><span class="p">:</span>
# ...

# %%
# %%
# the schemath objects hold their position relative to a root. so even when the
#
#     unexpanded = Schema.from_string\
# ```schema
# type: [integer, string]
# ```
#
#     expanded = Schema(oneOf=[
#         dict(type=x) for x in unexpanded["type"]
#     ])
#
#     for i in range(2):
#         assert expanded["oneOf", i, "type"].root == unexpanded
#         assert expanded["oneOf", i, "type"].root != expanded
# Out:
# <p>the schemath objects hold their position relative to a root. so even when the</p>
# <pre><code>unexpanded = Schema.from_string\
# </code></pre>
# <pre><code class="schema">type: [integer, string]
# </code></pre>
# <pre><code>expanded = Schema(oneOf=[
#     dict(type=x) for x in unexpanded[&quot;type&quot;]
# ])
#
# for i in range(2):
#     assert expanded[&quot;oneOf&quot;, i, &quot;type&quot;].root == unexpanded
#     assert expanded[&quot;oneOf&quot;, i, &quot;type&quot;].root != expanded</code></pre>

# %%
unexpanded = Schema(type=["integer", "string"])

# %%
expanded = Schema(oneOf=[
    dict(type=x) for x in unexpanded["type"]
])

# %%
expanded["oneOf", 0, "type"].root
# Out:
# {
#     "type": [
#         "integer",
#         "string"
#     ]
# }

# %%
Schema.from_string("""type: integer""")
# Out:
# {
#     "type": "integer"
# }

# %%
# %%
# ```yaml
# schema:
#     type: integer
# equivalences:
#     - oneOf: [{type: integer}]
#     - oneOf: [{oneOf: [{type: integer}]}]
#     - oneOf: [{oneOf: [{oneOf: [{type: integer}]}]}]
# ```
# Out:
# {'schema': {'type': 'integer'},
#  'equivalences': [{'oneOf': [{'type': 'integer'}]},
#   {'oneOf': [{'oneOf': [{'type': 'integer'}]}]},
#   {'oneOf': [{'oneOf': [{'oneOf': [{'type': 'integer'}]}]}]}]}
# <pre><code class="yaml"><div class="highlight"><pre><span></span><span class="nt">schema</span><span class="p">:</span>
# <span class="w">    </span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="l l-Scalar l-Scalar-Plain">integer</span>
# <span class="nt">equivalences</span><span class="p">:</span>
# <span class="w">    </span><span class="p p-Indicator">-</span><span class="w"> </span><span class="nt">oneOf</span><span class="p">:</span><span class="w"> </span><span class="p p-Indicator">[{</span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="nv">integer</span><span class="p p-Indicator">}]</span>
# ...

# %%
# %%
# ```yaml
# schema:
#     type: integer
# equivalences:
#     - oneOf: [{type: integer}]
#     - oneOf: [{oneOf: [{type: integer}]}]
#     - oneOf: [{oneOf: [{oneOf: [{type: integer}]}]}]
# ```
# Out:
# {'schema': {'type': 'integer'},
#  'equivalences': [{'oneOf': [{'type': 'integer'}]},
#   {'oneOf': [{'oneOf': [{'type': 'integer'}]}]},
#   {'oneOf': [{'oneOf': [{'oneOf': [{'type': 'integer'}]}]}]}]}
# <pre><code class="yaml"><div class="highlight"><pre><span></span><span class="nt">schema</span><span class="p">:</span>
# <span class="w">    </span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="l l-Scalar l-Scalar-Plain">integer</span>
# <span class="nt">equivalences</span><span class="p">:</span>
# <span class="w">    </span><span class="p p-Indicator">-</span><span class="w"> </span><span class="nt">oneOf</span><span class="p">:</span><span class="w"> </span><span class="p p-Indicator">[{</span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="nv">integer</span><span class="p p-Indicator">}]</span>
# ...

# %%
# %%
# ```yaml
# schema:
#     type: [integer, string]
# equivalences:
#     - oneOf:
#         - type: [integer, string]
#     - oneOf:
#         - type: integer
#         - type: string
#     - if:
#         type: integer
#       else:
#         type: string
#
#
# ```
# Out:
# {'schema': {'type': ['integer', 'string']},
#  'equivalences': [{'oneOf': [{'type': 'integer'}, {'type': 'string'}]}]}
# <pre><code class="yaml"><div class="highlight"><pre><span></span><span class="nt">schema</span><span class="p">:</span>
# <span class="w">    </span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="p p-Indicator">[</span><span class="nv">integer</span><span class="p p-Indicator">,</span><span class="w"> </span><span class="nv">string</span><span class="p p-Indicator">]</span>
# <span class="nt">equivalences</span><span class="p">:</span>
# <span class="w">    </span><span class="p p-Indicator">-</span><span class="w"> </span><span class="nt">oneOf</span><span class="p">:</span>
# <span class="w">        </span><span class="p p-Indicator">-</span><span class="w"> </span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="l l-Scalar l-Scalar-Plain">integer</span>
# ...

# %%
# %%
# ```yaml
# schema:
#     type: [integer, string]
# equivalences:
#     - oneOf:
#         - type: integer
#         - type: string
#
# ```
# Out:
# {'schema': {'type': ['integer', 'string']},
#  'equivalences': [{'oneOf': [{'type': 'integer'}, {'type': 'string'}]}]}
# <pre><code class="yaml"><div class="highlight"><pre><span></span><span class="nt">schema</span><span class="p">:</span>
# <span class="w">    </span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="p p-Indicator">[</span><span class="nv">integer</span><span class="p p-Indicator">,</span><span class="w"> </span><span class="nv">string</span><span class="p p-Indicator">]</span>
# <span class="nt">equivalences</span><span class="p">:</span>
# <span class="w">    </span><span class="p p-Indicator">-</span><span class="w"> </span><span class="nt">oneOf</span><span class="p">:</span>
# <span class="w">        </span><span class="p p-Indicator">-</span><span class="w"> </span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="l l-Scalar l-Scalar-Plain">integer</span>
# ...

# %%
# %%
# ```yaml
# schema:
#     if:
#         type: integer
#     then:
#         maximum: 10
#     else:
#         type: string
#         maxLength: 10
#
# equivalences:
#     - oneOf:
#         - type: integer
#         - type: string
# ```
# Out:
# {'schema': {'type': ['integer', 'string']},
#  'equivalences': [{'oneOf': [{'type': 'integer'}, {'type': 'string'}]}]}
# <pre><code class="yaml"><div class="highlight"><pre><span></span><span class="nt">schema</span><span class="p">:</span>
# <span class="w">    </span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="p p-Indicator">[</span><span class="nv">integer</span><span class="p p-Indicator">,</span><span class="w"> </span><span class="nv">string</span><span class="p p-Indicator">]</span>
# <span class="nt">equivalences</span><span class="p">:</span>
# <span class="w">    </span><span class="p p-Indicator">-</span><span class="w"> </span><span class="nt">oneOf</span><span class="p">:</span>
# <span class="w">        </span><span class="p p-Indicator">-</span><span class="w"> </span><span class="nt">type</span><span class="p">:</span><span class="w"> </span><span class="l l-Scalar l-Scalar-Plain">integer</span>
# ...
